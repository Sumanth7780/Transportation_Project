# %%
import pandas as pd

# Load the dataset
file_path = "D:\\0-transportation project\\code\\for_100\\common_pcards\\common_pcards_00.csv"

data = pd.read_csv(file_path)

# Display the first few rows of the dataframe to understand its structure
data.head()
# Out:
#        Common_Pcard
# 0  G0CF90GE9EBFECEC
# 1  000E0E0FB0CG9FBF
# 2  BG0F5B9F0B6500F9
# 3  E50E0E9000CCC0CE
# 4  000E0E0E9CE06C5C

# %%
# Randomly sample 100 users from the dataset
sampled_users = data

# Display the sampled users
sampled_users
# Out:
#           Common_Pcard
# 0     G0CF90GE9EBFECEC
# 1     000E0E0FB0CG9FBF
# 2     BG0F5B9F0B6500F9
# 3     E50E0E9000CCC0CE
# 4     000E0E0E9CE06C5C
# ...                ...
# 9618  0EEE0FG0000GFFFF
# 9619  C3F5ECGC60CC6B05
# 9620  000E0E05CC03CEEB
# 9621  000E0E03C66CFF50
# 9622  B0C53E000699BFG5
#
# [9623 rows x 1 columns]

# %%
sampled_users.to_csv("D:\\0-transportation project\\code\\for_100\\sample_100.csv", index=False)

# %%
def filter_data_based_on_pcards(sampled_users, data_df, output_file_path=None):
    """
    Filters data based on a list of common PCards.

    Parameters:
    - common_pcards_path: str, path to the CSV file containing common PCards.
    - data_file_path: str, path to the CSV file containing data to be filtered.
    - output_file_path: str, optional, path to save the filtered data as a CSV file.

    Returns:
    - DataFrame containing filtered data.
    """


    # Filter the data
    filtered_data = data_df[data_df['PCARD_NO'].isin(sampled_users)]

    # Save the filtered data to a CSV file if an output path is provided
    if output_file_path:
        filtered_data.to_csv(output_file_path, index=False)
        print(f"Filtered data saved to {output_file_path}")

    return filtered_data

# %%
df1 = pd.read_csv("E:\\data\\201301\\unique_pcard\\01_100.csv")
df2 = pd.read_csv("E:\\data\\201302\\unique_pcard\\02_100.csv")
df3 = pd.read_csv("E:\\data\\201303\\unique_pcard\\03_100.csv")
df4 = pd.read_csv("E:\\data\\201304\\unique_pcard\\04_100.csv")
df5 = pd.read_csv("E:\\data\\201305\\unique_pcard\\05_100.csv")
df6 = pd.read_csv("E:\\data\\201306\\unique_pcard\\06_100.csv")
df7 = pd.read_csv("E:\\data\\201307\\unique_pcard\\07_100.csv")
df8 = pd.read_csv("E:\\data\\201308\\unique_pcard\\08_100.csv")
df9 = pd.read_csv("E:\\data\\201309\\unique_pcard\\09_100.csv")
df10 = pd.read_csv("E:\\data\\201310\\unique_pcard\\10_100.csv")
df11= pd.read_csv("E:\\data\\201311\\unique_pcard\\11_100.csv")
df12 = pd.read_csv("E:\\data\\201312\\unique_pcard\\12_100.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df11,df12], ignore_index=True)
print(df)
# Define the list of sampled users
sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\comman_pcards_data.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
#                    PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 0      E00E000E0000CEGFBCEE  20130113180137         9               105
# 1      E00E000E0000CEGFBCEE  20130113193031        10               105
# 2      E00E000E000E0CBF9FC5  20130113142629        12               120
# 3      E00E000E000E0CBF9FC5  20130113144433        12               120
# 4      E00E000E000E0CBF9FC5  20130113200746        13               200
# ...                     ...             ...       ...               ...
# 24041      E909F90C00CEG5E0  20131219161722        41               200
# 24042      E909F90C00CEG5E0  20131219211405        42               120
# 24043      E909F90C9ECB990B  20131219055359        81               200
# 24044      E909F909FGBB0006  20131219225541        38               200
# 24045      E909F909FGBB0006  20131219120342        37               200
#
#        TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201301\\unique_pcard\\01_13.csv")

df2 = pd.read_csv("E:\\data\\201301\\unique_pcard\\01_14.csv")
df3 = pd.read_csv("E:\\data\\201301\\unique_pcard\\01_15.csv")
df4 = pd.read_csv("E:\\data\\201301\\unique_pcard\\01_16.csv")
df5 = pd.read_csv("E:\\data\\201301\\unique_pcard\\01_17.csv")
df6 = pd.read_csv("E:\\data\\201301\\unique_pcard\\01_18.csv")
df7 = pd.read_csv("E:\\data\\201301\\unique_pcard\\01_19.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
print(df)
# Define the list of sampled users
sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201301\\unique_pcard\\01_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
#                     PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 0       E00E0000500000GB5609  20130113091321         1               105
# 1       E00E0000500000GB5609  20130113212157         2               120
# 2       E00E0000500000GB5609  20130113214519         2               105
# 3       E00E000E000005G95FFC  20130113054935        13               115
# 4       E00E000E000005G95FFC  20130113052856        13               120
# ...                      ...             ...       ...               ...
# 175907      E909F909G5E6FB06  20130119191705        12               200
# 175908      E909F909G5E6FB06  20130119200511        12               115
# 175909      E909F909FGBB0006  20130119222710        19               200
# 175910      E909F909FGBB0006  20130119114944        18               200
# 175911      GC09F90F0F905305  20130119180907        27               115
#
#         TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201302\\unique_pcard\\02_13.csv")
df2 = pd.read_csv("E:\\data\\201302\\unique_pcard\\02_14.csv")
df3 = pd.read_csv("E:\\data\\201302\\unique_pcard\\02_15.csv")
df4 = pd.read_csv("E:\\data\\201302\\unique_pcard\\02_16.csv")
df5 = pd.read_csv("E:\\data\\201302\\unique_pcard\\02_12.csv")
df6 = pd.read_csv("E:\\data\\201302\\unique_pcard\\02_11.csv")
df7 = pd.read_csv("E:\\data\\201302\\unique_pcard\\02_10.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)

# Define the list of sampled users
sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201302\\unique_pcard\\02_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
# Filtered data saved to E:\data\201302\unique_pcard\02_100.csv
#                  PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 129  E00E000E0000CEGFBCEE  20130213053656        11               120
# 130  E00E000E0000CEGFBCEE  20130213065727        12               105
# 209  E00E000E000E0CBF9FC5  20130213084601        15               120
# 210  E00E000E000E0CBF9FC5  20130213090406        15               120
# 211  E00E000E000E0CBF9FC5  20130213234551         1               120
#
#      TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# 129          0    41110086.0            111004500  111752676.0
# 130          0    11110631.0            111512470  111707307.0
# 209          0    11110899.0            111008800  111744930.0
# 210          1    11110144.0            111003500  111751382.0
# 211          1    11110899.0            111008800  111744901.0
#
#      PCARD_USER_CLASS_CD  RIDE_STA_ID  ...  ALIGHT_AMT  RUN_DEPART_DTIME  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201303\\unique_pcard\\03_13.csv")
df2 = pd.read_csv("E:\\data\\201303\\unique_pcard\\03_14.csv")
df3 = pd.read_csv("E:\\data\\201303\\unique_pcard\\03_15.csv")
df4 = pd.read_csv("E:\\data\\201303\\unique_pcard\\03_16.csv")
df5 = pd.read_csv("E:\\data\\201303\\unique_pcard\\03_12.csv")
df6 = pd.read_csv("E:\\data\\201303\\unique_pcard\\03_11.csv")
df7 = pd.read_csv("E:\\data\\201303\\unique_pcard\\03_10.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
print(df)
# Define the list of sampled users
sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201303\\unique_pcard\\03_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
#                     PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 0       E00E0000500000GB5609  20130313082503         6               120
# 1       E00E0000500000GB5609  20130313080604         6               105
# 2       E00E0000500000GB5609  20130313214749         7               105
# 3       E00E0000500000GB5609  20130313212312         7               115
# 4       E00E000E000005G95FFC  20130313064913         1               115
# ...                      ...             ...       ...               ...
# 177298      E909F909FGBB0006  20130310112122        17               200
# 177299      E909F909FGBB0006  20130310222358        18               200
# 177300      GC09F90F0F905305  20130310190842        17               115
# 177301      GC09F90F0F905305  20130310194842        18               105
# 177302      GC09F90F0F905305  20130310061850        16               115
#
#         TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201304\\unique_pcard\\04_17.csv")
df2 = pd.read_csv("E:\\data\\201304\\unique_pcard\\04_14.csv")
df3 = pd.read_csv("E:\\data\\201304\\unique_pcard\\04_15.csv")
df4 = pd.read_csv("E:\\data\\201304\\unique_pcard\\04_16.csv")
df5 = pd.read_csv("E:\\data\\201304\\unique_pcard\\04_18.csv")
df6 = pd.read_csv("E:\\data\\201304\\unique_pcard\\04_19.csv")
df7 = pd.read_csv("E:\\data\\201304\\unique_pcard\\04_20.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
print(df)
# Define the list of sampled users
sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201304\\unique_pcard\\04_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
#                     PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 0       E00E0000500000GB5609  20130417075247         9               105
# 1       E00E0000500000GB5609  20130417080916         9               115
# 2       E00E0000500000GB5609  20130417214359        10               115
# 3       E00E0000500000GB5609  20130417221147        10               105
# 4       E00E000E000005G95FFC  20130417053341         1               115
# ...                      ...             ...       ...               ...
# 177769      E909F909G5E6FB06  20130420084125         8               115
# 177770      E909F909G5E6FB06  20130420210839         9               200
# 177771      E909F909G5E6FB06  20130420222556         9               115
# 177772      E909F909FGBB0006  20130420101243         7               200
# 177773      GC09F90F0F905305  20130420072523        91               115
#
#         TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201305\\unique_pcard\\05_17.csv")
df2 = pd.read_csv("E:\\data\\201305\\unique_pcard\\05_14.csv")
df3 = pd.read_csv("E:\\data\\201305\\unique_pcard\\05_15.csv")
df4 = pd.read_csv("E:\\data\\201305\\unique_pcard\\05_16.csv")
df5 = pd.read_csv("E:\\data\\201305\\unique_pcard\\filtered_05_18.csv",encoding='ISO-8859-1')
df6 = pd.read_csv("E:\\data\\201305\\unique_pcard\\05_13.csv")
df7 = pd.read_csv("E:\\data\\201305\\unique_pcard\\05_12.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
print(df)
# Define the list of sampled users
sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201305\\unique_pcard\\05_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
#                     PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 0       E00E0000500000GB5609  20130517075953         9               105
# 1       E00E0000500000GB5609  20130517081247         9               120
# 2       E00E0000500000GB5609  20130517215933        10               105
# 3       E00E0000500000GB5609  20130517213737        10               115
# 4       E00E000E000005G95FFC  20130517175146         3               115
# ...                      ...             ...       ...               ...
# 177935      E909F909FGBB0006  20130512150847        48               200
# 177936      E909F909FGBB0006  20130512225000        49               200
# 177937      GC09F90F0F905305  20130512062021        29               115
# 177938      GC09F90F0F905305  20130512191709        30               200
# 177939      GC09F90F0F905305  20130512191058        30               105
#
#         TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201306\\unique_pcard\\06_15.csv")
df2 = pd.read_csv("E:\\data\\201306\\unique_pcard\\06_14.csv")
df3 = pd.read_csv("E:\\data\\201306\\unique_pcard\\06_13.csv")
df4 = pd.read_csv("E:\\data\\201306\\unique_pcard\\06_12.csv")
df5 = pd.read_csv("E:\\data\\201306\\unique_pcard\\06_11.csv")
df6 = pd.read_csv("E:\\data\\201306\\unique_pcard\\06_10.csv")
df7 = pd.read_csv("E:\\data\\201306\\unique_pcard\\06_09.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
print(df)
# Define the list of sampled users
sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201306\\unique_pcard\\06_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
#                     PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 0       E00E0000500000GB5609  20130615081114        10               115
# 1       E00E0000500000GB5609  20130615220619        11               120
# 2       E00E0000500000GB5609  20130615222624        11               105
# 3       E00E0000500000GB5609  20130615075739        10               105
# 4       E00E000E000005G95FFC  20130615062132         6               120
# ...                      ...             ...       ...               ...
# 179200      E909F909FGBB0006  20130609143248         8               105
# 179201      E909F909FGBB0006  20130609235855        10               120
# 179202      E909F909FGBB0006  20130609143622         8               115
# 179203      E909F909FGBB0006  20130609164326         9               200
# 179204      GC09F90F0F905305  20130609180136        79               115
#
#         TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201307\\unique_pcard\\07_17.csv")
df2 = pd.read_csv("E:\\data\\201307\\unique_pcard\\07_14.csv")
df3 = pd.read_csv("E:\\data\\201307\\unique_pcard\\07_15.csv")
df4 = pd.read_csv("E:\\data\\201307\\unique_pcard\\07_16.csv")
df5 = pd.read_csv("E:\\data\\201307\\unique_pcard\\07_18.csv")
df6 = pd.read_csv("E:\\data\\201307\\unique_pcard\\07_19.csv")
df7 = pd.read_csv("E:\\data\\201307\\unique_pcard\\07_20.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
# Define the list of sampled users
sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201307\\unique_pcard\\07_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
# Filtered data saved to E:\data\201307\unique_pcard\07_100.csv
#                  PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 137  E00E000E0000CEGFBCEE  20130717094504         8               200
# 138  E00E000E0000CEGFBCEE  20130717103944         9               200
# 220  E00E000E000E0CBF9FC5  20130717150037         2               120
# 221  E00E000E000E0CBF9FC5  20130717145349         2               120
# 222  E00E000E000E0CBF9FC5  20130717163031         3               115
#
#      TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# 137          0           NaN            211000000          NaN
# 138          0           NaN            211000000          NaN
# 220          1    11110899.0            111008800  111744901.0
# 221          0    11110144.0            111003500  111743528.0
# 222          1    11110006.0            111008800  111751398.0
#
#      PCARD_USER_CLASS_CD  RIDE_STA_ID  ...  ALIGHT_AMT  RUN_DEPART_DTIME  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201309\\unique_pcard\\09_08.csv")
df2 = pd.read_csv("E:\\data\\201309\\unique_pcard\\09_14.csv")
df3 = pd.read_csv("E:\\data\\201309\\unique_pcard\\09_10.csv")
df4 = pd.read_csv("E:\\data\\201309\\unique_pcard\\09_09.csv")
df5 = pd.read_csv("E:\\data\\201309\\unique_pcard\\09_13.csv")
df6 = pd.read_csv("E:\\data\\201309\\unique_pcard\\09_12.csv")
df7 = pd.read_csv("E:\\data\\201309\\unique_pcard\\09_11.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
# Define the list of sampled users

sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201309\\unique_pcard\\09_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
# Filtered data saved to E:\data\201309\unique_pcard\09_100.csv
#                  PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 132  E00E000E0000CEGFBCEE  20130908205732        10               105
# 133  E00E000E0000CEGFBCEE  20130908223320        11               105
# 213  E00E000E000E0CBF9FC5  20130908134827        13               120
# 214  E00E000E000E0CBF9FC5  20130908132807        13               120
# 215  E00E000E000E0CBF9FC5  20130908224216        14               120
#
#      TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# 132          0    11110631.0            111512470  111707308.0
# 133          0    11110631.0            111512470  111707206.0
# 213          1    11110144.0            111003500  111751382.0
# 214          0    11110142.0            111007200  111748172.0
# 215          0    11110865.0            111009080  111706613.0
#
#      PCARD_USER_CLASS_CD  RIDE_STA_ID  ...  ALIGHT_AMT  RUN_DEPART_DTIME  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201308\\unique_pcard\\08_17.csv")
df2 = pd.read_csv("E:\\data\\201308\\unique_pcard\\08_14.csv")
df3 = pd.read_csv("E:\\data\\201308\\unique_pcard\\08_15.csv")
df4 = pd.read_csv("E:\\data\\201308\\unique_pcard\\08_16.csv")
df5 = pd.read_csv("E:\\data\\201308\\unique_pcard\\08_13.csv")
df6 = pd.read_csv("E:\\data\\201308\\unique_pcard\\08_12.csv")
df7 = pd.read_csv("E:\\data\\201308\\unique_pcard\\08_11.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
# Define the list of sampled users

sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201308\\unique_pcard\\08_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
# Filtered data saved to E:\data\201308\unique_pcard\08_100.csv
#                  PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 135  E00E000E0000CEGFBCEE  20130817103745        13               105
# 136  E00E000E0000CEGFBCEE  20130817094253        12               105
# 217  E00E000E000E0CBF9FC5  20130817194052        15               120
# 218  E00E000E000E0CBF9FC5  20130817195707        15               120
# 219  E00E000E000E0CBF9FC5  20130817231809         1               120
#
#      TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# 135          0    11111158.0            111504370  111755167.0
# 136          0    11111158.0            111504370  111755180.0
# 217          0    11110865.0            111009080  111753132.0
# 218          1    11110142.0            111007200  111748148.0
# 219          0    11110142.0            111007200  111748137.0
#
#      PCARD_USER_CLASS_CD  RIDE_STA_ID  ...  ALIGHT_AMT  RUN_DEPART_DTIME  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201310\\unique_pcard\\10_17.csv")
df2 = pd.read_csv("E:\\data\\201310\\unique_pcard\\10_14.csv")
df3 = pd.read_csv("E:\\data\\201310\\unique_pcard\\10_15.csv")
df4 = pd.read_csv("E:\\data\\201310\\unique_pcard\\10_16.csv")
df5 = pd.read_csv("E:\\data\\201310\\unique_pcard\\10_13.csv")
df6 = pd.read_csv("E:\\data\\201310\\unique_pcard\\10_18.csv")
df7 = pd.read_csv("E:\\data\\201310\\unique_pcard\\10_19.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
# Define the list of sampled users

sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201310\\unique_pcard\\10_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
# Filtered data saved to E:\data\201310\unique_pcard\10_100.csv
#                  PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 143  E00E000E0000CEGFBCEE  20131017094315        12               200
# 144  E00E000E0000CEGFBCEE  20131017104126        13               200
# 232  E00E000E000E0CBF9FC5  20131018000459         6               120
# 233  E00E000E000E0CBF9FC5  20131017153023         5               120
# 634  E00E000G0E00FC3FG99G  20131017173101         2               120
#
#      TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# 143          0           NaN            211000000          NaN
# 144          0           NaN            211000000          NaN
# 232          0    11110139.0            111007200  111748184.0
# 233          0    11110139.0            111007200  111742356.0
# 634          0    11110241.0            111007800  111749998.0
#
#      PCARD_USER_CLASS_CD  RIDE_STA_ID  ...  ALIGHT_AMT  RUN_DEPART_DTIME  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201311\\unique_pcard\\11_12.csv")
df2 = pd.read_csv("E:\\data\\201311\\unique_pcard\\11_14.csv")
df3 = pd.read_csv("E:\\data\\201311\\unique_pcard\\11_15.csv")
df4 = pd.read_csv("E:\\data\\201311\\unique_pcard\\11_16.csv")
df5 = pd.read_csv("E:\\data\\201311\\unique_pcard\\11_13.csv")
df6 = pd.read_csv("E:\\data\\201311\\unique_pcard\\11_11.csv")
df7 = pd.read_csv("E:\\data\\201311\\unique_pcard\\11_10.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
# Define the list of sampled users

sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201311\\unique_pcard\\11_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
# Filtered data saved to E:\data\201311\unique_pcard\11_100.csv
#                  PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 134  E00E000E0000CEGFBCEE  20131112184818         6               105
# 135  E00E000E0000CEGFBCEE  20131112193638         7               105
# 227  E00E000E000E0CBF9FC5  20131112161814        14               120
# 651  E00E000G0E00FC3FG99G  20131112055135         8               120
# 652  E00E000G0E00FC3FG99G  20131112172946         9               120
#
#      TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# 134          0    11111158.0            111504370  111707272.0
# 135          0    11111158.0            111504370  111755167.0
# 227          0    11110899.0            111008800  111744930.0
# 651          0    11110241.0            111007800  111743777.0
# 652          0    11110241.0            111007800  111749741.0
#
#      PCARD_USER_CLASS_CD  RIDE_STA_ID  ...  ALIGHT_AMT  RUN_DEPART_DTIME  \
# ...

# %%
df1 = pd.read_csv("E:\\data\\201312\\unique_pcard\\12_17.csv")
df2 = pd.read_csv("E:\\data\\201312\\unique_pcard\\12_20.csv")
df3 = pd.read_csv("E:\\data\\201312\\unique_pcard\\12_15.csv")
df4 = pd.read_csv("E:\\data\\201312\\unique_pcard\\12_16.csv")
df5 = pd.read_csv("E:\\data\\201312\\unique_pcard\\12_21.csv")
df6 = pd.read_csv("E:\\data\\201312\\unique_pcard\\12_18.csv")
df7 = pd.read_csv("E:\\data\\201312\\unique_pcard\\12_19.csv")
df = pd.concat([df1,df2,df3,df4,df5,df6,df7], ignore_index=True)
# Define the list of sampled users

sampled_user_ids = sampled_users['Common_Pcard'].tolist()
output_file_path = "E:\\data\\201312\\unique_pcard\\12_100.csv"  # Optional

filtered_combined_data = filter_data_based_on_pcards(sampled_user_ids, df, output_file_path)

# Display the filtered data
filtered_combined_data.head()
# Out:
# Filtered data saved to E:\data\201312\unique_pcard\12_100.csv
#                  PCARD_NO      RIDE_DTIME  TRANS_ID  TRANSP_METHOD_CD  \
# 123  E00E000E0000CEGFBCEE  20131217185217         5               105
# 124  E00E000E0000CEGFBCEE  20131217193941         6               105
# 214  E00E000E000E0CBF9FC5  20131217193433        15               120
# 215  E00E000E000E0CBF9FC5  20131217160811        14               120
# 649  E00E000G0E00FC3FG99G  20131217174025        15               120
#
#      TRAF_FREQ  BUS_ROUTE_ID  RIDE_TRANSP_BIZR_ID      VEHC_ID  \
# 123          0    11111158.0            111504370  111707272.0
# 124          0    11111158.0            111504370  111707209.0
# 214          0    11110139.0            111007200  111706896.0
# 215          0    11110139.0            111007200  111706899.0
# 649          0    11110241.0            111007800  111743709.0
#
#      PCARD_USER_CLASS_CD  RIDE_STA_ID  ...  ALIGHT_AMT  RUN_DEPART_DTIME  \
# ...
